# %% [markdown]
# # Lab 0.2 — Breadboard Continuity + Resistor Measurement
#
# Lab page: https://www.diiv.io/course3/lab-0-2-breadboard-continuity-resistors.html
#
# Simulate first: build the reference here in NumPy/SciPy, *then* write the C.
# Measured values and reconciliation belong in `../notes.md`.

# %%
import numpy as np
import scipy.signal as signal
import matplotlib.pyplot as plt

from pathlib import Path

CAPTURES = Path('../captures')   # instrument exports land here
# %matplotlib inline

# %% [markdown]
# ## 1 — Reference implementation
#
# The NumPy/SciPy version of what the device will compute.

# %% [markdown]
# ## 2 — Load the capture
#
# Siglent CSV / Saleae export / serial log from `../captures/`.

# %% [markdown]
# ## 3 — Device output vs. reference

# %% [markdown]
# ## 4 — Predicted vs. measured
#
# Numbers here; the written reconciliation goes in `../notes.md`.
